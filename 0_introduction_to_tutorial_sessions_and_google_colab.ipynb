# %% [markdown]
# <a href="https://colab.research.google.com/github/pserebrennikov/3rd-year-project/blob/master/0_introduction_to_tutorial_sessions_and_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial 0 - Introduction to tutorial sessions and Google Colab
# ### Course on Optimization for Machine Learning - Dr. F. Ballarin
# ### Master Degree in Data Analytics for Business, Catholic University of the Sacred Heart, Milano

# %% [markdown]
# ## What should you do? - before the tutorial session
# 1. (only once) We will be using [Google Colab](https://colab.research.google.com/), an online platform that allows us to write and execute Python code in our browser without any local installation. To fully access the platform you must have a [Google Account](https://accounts.google.com/), associated either to your personal [@gmail.com](https://www.gmail.com/) email address or to your [@icatt.it](https://icatt.unicatt.it/) email address.
# 2. I will share on Blackboard a link to a notebook containing the exercises that we will discuss during the class. Make sure to be registered to the course on Blackboard, and check the course materials before the tutorial session starts to find the link to the notebook we are going to use.

# %% [markdown]
# ## What should you do? - during the tutorial session
# 1. Make sure you are logged in with your [Google Account](https://accounts.google.com/).
# 2. Follow the link on Blackboard, and create a copy of the tutorial notebook using the menu "File -> Save a copy in Drive".
# ![Copy the notebook in your Google Drive](data:image/png;base64,...)
# 3. This will create a copy of the notebook in your [Google Drive](https://drive.google.com/), in a folder called "Colab Notebooks", to which you may go in future if you want to revise what we did during the tutorial session.
# ![Copy the notebook in your Google Drive](data:image/png;base64,...)
# 4. You may share your copy with me, by clicking on "Share" in the top right of the screen, and then typing my email address.
# ![Share your notebook with me (part 1)](data:image/png;base64,...)
# ![Share your notebook with me (part 2)](data:image/png;base64,...)
#   Feel free to interrupt me at any time if you have questions. Sharing your copy with me is especially beneficial when during the class you ask me a question related to the implementation (e.g., you have a Python error which you do not know how to fix) because I will go to the notebook you are working on, easily open it on my device and work out the answer with you.
# 6. You may run the entire notebook at once, or cell by cell.
# 7. You may add comments in any code cell, e.g. if you want to annotate some of my comments during the class. By default, I will not be notified of new comments (see below on what to do to send me a notification), so you may consider these comments as notes to yourselves.
# ![You may add a comment to yourself](data:image/png;base64,...)

# %% [markdown]
# ## What should you do? - after the tutorial session
# 1. I will share on Blackboard a link to a notebook containing the homework.
# 2. Make sure you are logged in with your [Google Account](https://accounts.google.com/).
# 3. Follow the link on Blackboard, and create a copy of the homework notebook using the menu "File -> Save a copy in Drive" (as above).
# 4. Carry out the homework on your own time. If need be, you may upload a picture of you paper sheet to your Google Drive, and include it in the notebook as [explained in this post](https://stackoverflow.com/questions/50670920/how-to-insert-an-inline-image-in-google-colaboratory-from-google-drive).
# 5. When you are done with the homework, or if you have questions, share your copy with my email address (as above).
# 6. If you have specific questions on the implementation (e.g., you have a Python error which you do not know how to fix) you may add a comment on the affected cell and *mention* my email address as follows:
# ![You may add a comment to yourself](data:image/png;base64,...)
# Please *remember* to mention my email address if you want me to reply to your comment, otherwise I would not get a notification of your question. You may write the comment in Italian or in English, and I will reply using the same language.
# 7. You may also want to send me an email anyway, especially if you believe that it might be beneficial for you to setup a meeting to have a more thorough discussion on your questions on the tutorial/homework.
